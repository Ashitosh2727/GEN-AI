# %% [markdown]
# Introduction to Stremlit
#
# Stremlit is an open - source freamwork for machine leaning and data science projects.
# It allows to create beautiful web applications for machine learning and data science projects with simple python scripts
