# %%
## Create new Directory

import os

new_directory = "Package2"
os.mkdir(new_directory)
print(f"Directory {new_directory} create")
# Out:
# Directory Package2 create

# %%
## Listing files And directories

items = os.listdir('.')
print(items)
# Out:
# ['6.1-fileOperation.ipynb', '6.2-filePath.ipynb', 'destination.txt', 'example.bin', 'example.txt', 'Package', 'Package2']

# %%
## joining paths

dir_name = "folder"
file_name = "file.txt"

full_path = os.path.join(dir_name, file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
dir_name = "folder"
file_name = "file.txt"

full_path = os.path.join(os.getcwd(),dir_name, file_name)
print(full_path)
# Out:
# d:\python\6-File Handling\folder\file.txt

# %%
path = "example1.txt"
if os.path.exists(path):
    print(f"The path '{path}' exists")
else:
    print(f"The path '{path} doesn't exists")
# Out:
# The path 'example1.txt doesn't exists

# %%
## Checking if a path is a file or directory

path = "example.txt"

if os.path.isfile(path):
    print(f"The path '{path}' is a file.")
elif os.path.isdir(path):
    print(f"The path '{path}' is a directory")
else:
    print(f"The path '{path} is neither a file nor directory'")
# Out:
# The path 'example.txt' is a file.

# %%
## Checking the absoulte path

realtive_path = 'example.txt'
absoulte_path = os.path.abspath(realtive_path)
print(absoulte_path)
# Out:
# d:\python\6-File Handling\example.txt
