# %%
## Basic Syntax and Rules in Python
## Case Sensitivity - Python is Case Sensitive 

name = "Ashitosh"
Name = "Mane"

print(name)
print(Name)
# Out:
# Ashitosh
# Mane

# %%
## Indentation

age = 32

if age > 30:
    print(age)

print(age)
# Out:
# 32
# 32

# %%
## Line Continuation

total = 1+2+3+4+5+6+7+\
4+5+6

print(total)
# Out:
# 43

# %%
## Multiple Statemens On a Single line 

x = 5; y = 10; z = x + y;

print(z)
# Out:
# 15

# %%
## Understanding Semantics in Python
# Variable Assignment

age = 32
name = "Ashitosh"

# %%
## Type Inference
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
## Code Example of identation

if True:
    print("Correct Identation")
    if False:
        print("This ont print")
    print("This will Print")
print("Outside the if block")
# Out:
# Correct Identation
# This will Print
# Outside the if block
