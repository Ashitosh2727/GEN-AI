# %%
## if Statement

age = 20

if age >= 18:
    print("You are allowed to vote in the elections")
# Out:
# You are allowed to vote in the election

# %%
## else

age = 16

if age >= 18:
    print("Yor are eligible for voting")
else:
    print("You are a minor")
# Out:
# You are a minor

# %%
## elif

age = 20

if age<13:
    print("You are a child")
elif age<18:
    print("You are teenager")
else:
    print("You are an adult")
# Out:
# You are an adult

# %%
## Nested Conditional Statement

num = int(input("Enter the number"))

if num >= 0:
    print("The number is positive")
    if num % 2 == 0:
        print("The number is even")
    else:
        print("The number is odd")
else:
    print("The number is negative")
# Out:
# The number is positive
# The number is even

# %%
## Practical examples

## Determine if a year is leaf year using nested condition statement

year = int(input("Enter the year"))

if year % 4 == 0:
    if year % 100 == 0:
        if year % 400:
            print(year,"is a leap year")
        else:
            print(year,"is not a leaf year")
    else:
        print(year,"is a leaf year")
else:
    print(year,"is not a leaf year")
# Out:
# 2004 is a leaf year

# %%
## Assignment
## Simple Calculator

# Take user input
num1 = int(input("Enter first number"))
num2 = int(input("Enter second number"))

opeartion = input("Enter opeartion (+, -, *, /): ")

# Perform the requested operation

if opeartion == '+':
    result = num1 + num2
elif opeartion == '-':
    result = num1 - num2
elif opeartion == '*':
    result = num1 * num2
elif opeartion == '/':
    result = num1 / num2
else:
    result = "invalid operation"

print("Result:",result)
# Out:
# Result: 5

# %%
## Determine the ticket price based on age and wheather the is a student

# Take user input

age = int(input("Enter your age:"))
is_student = input("Are you student (yes/no): ").lower()

# Detrermine ticket price 

if age < 5:
    price = "Free"
elif age <= 12:
    price = "$10"
elif age <= 17:
    if is_student == "yes":
        price = "$12"
    else:
        price = "$15"
elif age <= 64:
    if is_student == "yes":
        price = "$18"
    else:
        price = "25"
else:
    price = "$20"

print("Ticket Price:",price)
# Out:
# Ticket Price: $10
